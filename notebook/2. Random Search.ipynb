# %% [markdown]
# # 2. Random Search
# ### Random Search for maximize problem

# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show
#Define the function in 3D
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

# %%
# Random Search for maximize problem
def z_func(x1,x2):
    return (3*(1-x1)**2*np.exp(-x1**2-(x2+1)**2)
            +10*(x1/5 -x1**3-x1**5)*np.exp(-x1**2-x2**2) 
            -1/3*np.exp(-(x1+1)**2-x2**2))
# range from -3 to 3 for each x1 and x2
x1 = np.arange(-3.0,3.0,0.1)
x2 = np.arange(-3.0,3.0,0.1)
X,Y = meshgrid(x1, x2) # grid of point
Z = z_func(X, Y) # evaluation of the function on the grid
im = imshow(Z,cmap=cm.RdBu) # drawing the function
# latex fashion title
colorbar(im) # adding the colobar on the right
title('Equation 2')
show()

#Define the function in 3D
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, 
                      cmap=cm.RdBu,linewidth=0, antialiased=False)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
ax.view_init(elev=30., azim=-25, roll=0)
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
## Optimization process
# Define number of interations
n_iter =300;
# Random starting point
range_x =[-3, 3, -3, 3] # Range x in x1[-3, 3] and x2[-3, 3] 
x1_start = 1.5
x2_start = 2.8
# x1 and x2 array
x1_array=[]
x2_array=[]
def random_search(x1, x2, n_iter):
    #Random Search
    zn1 =[]; zn2=[];
    for i in range(n_iter):
        if ((x1 >= range_x[0]) and (x1 <= range_x[1]) 
            and (x2 >= range_x[2]) and (x2 <= range_x[3])):
            zn1 = z_func(x1, x2)
        else:
            zn1 =-1000
        # A new solution is produce
        x1n = x1 + np.random.randn(1)*1
        x2n = x2 + np.random.randn(1)*1
        if ((x1n >= range_x[0]) and (x1n <= range_x[1]) 
            and (x2n >= range_x[2]) and (x2n <= range_x[3])):
            zn2 = z_func(x1n, x2n)
        else:
            zn2 =-1000
        if (zn2 > zn1):
            x1 = x1n
            x2 = x2n
        x1_array.append(x1)
        x2_array.append(x2)
        print(x1)
        print(x2)
random_search(x1_start, x2_start, n_iter)
# Out:
# 1.5
# 2.8
# 1.5
# 2.8
# 1.5
# 2.8
# 1.5
# 2.8
# 1.5
# 2.8
# [-0.87733026]
# [2.28698096]
# [-0.87733026]
# [2.28698096]
# [-0.87733026]
# [2.28698096]
# [-0.87733026]
# [2.28698096]
# [-1.99173599]
# [2.38945732]
# [-1.6062788]
# [1.85273812]
# [-1.51654417]
# [1.18188449]
# [-2.04609946]
# [-0.36303478]
# [-2.04609946]
# [-0.36303478]
# [-2.04609946]
# [-0.36303478]
# [-2.04609946]
# [-0.36303478]
# [-1.50973084]
# [-0.3402541]
# [-1.50973084]
# [-0.3402541]
# [-1.50973084]
# [-0.3402541]
# [-1.50973084]
# [-0.3402541]
# [-1.50973084]
# [-0.3402541]
# [-1.50973084]
# [-0.3402541]
# [-1.50973084]
# [-0.3402541]
# [-1.50973084]
# [-0.3402541]
# [-1.50973084]
# [-0.3402541]
# [-1.50973084]
# [-0.3402541]
# [-1.50973084]
# [-0.3402541]
# [-1.50973084]
# [-0.3402541]
# [-1.37207703]
# [0.14577695]
# [-1.37207703]
# [0.14577695]
# [-1.37207703]
# [0.14577695]
# [-1.37207703]
# [0.14577695]
# [-1.37207703]
# [0.14577695]
# [-1.37207703]
# [0.14577695]
# [-1.37207703]
# [0.14577695]
# ...

# %%
# Draw the Contour
def z_func(x1,x2):
    return (3*(1-x1)**2*np.exp(-x1**2-(x2+1)**2)
            +10*(x1/5 -x1**3-x1**5)*np.exp(-x1**2-x2**2) 
            -1/3*np.exp(-(x1+1)**2-x2**2))
# range from -3 to 3 for each x1 and x2
x1 = np.arange(-3.0,3.0,0.1)
x2 = np.arange(-3.0,3.0,0.1)
X,Y = meshgrid(x1, x2) # grid of point
Z = z_func(X, Y) # evaluation of the function on the grid
fig,ax=plt.subplots(1,1)
# Add contour
cp = ax.contourf(X, Y, Z)
fig.colorbar(cp) # Add a colorbar to a plot
plt.plot(x1_array, x2_array, marker="o", markersize=8, markeredgecolor="white", markerfacecolor="red")
# latex fashion title
title('Equation 2')
show()
